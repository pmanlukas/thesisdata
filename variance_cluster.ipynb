# %% [markdown]
# # Variance Cluster
#
# In this notebook the variance of the resulting clusters and for the clustering on the older versions of the OAS files, is calculated

# %% [markdown]
# ## Imports and loading of data

# %%
import pickle
import json
import pandas as pd
import numpy as np
import sys
import matplotlib.pyplot as plt

# %%
col_list = ['swagger','info','host','basePath','schemes','consumes','produces','paths','definitions','parameters','responses','securityDefinitions','security','tags','externalDocs','title','description','termsOfService','contact','license','version']
col_list
# Out:
# ['swagger',
#  'info',
#  'host',
#  'basePath',
#  'schemes',
#  'consumes',
#  'produces',
#  'paths',
#  'definitions',
#  'parameters',
#  'responses',
#  'securityDefinitions',
#  'security',
#  'tags',
#  'externalDocs',
#  'title',
#  'description',
#  'termsOfService',
#  'contact',
#  'license',
#  'version']

# %%
struct_diff_df = pd.read_csv('PAMcomplete_diff.csv',index_col='X')
struct_diff_df = struct_diff_df.iloc[:,1:]
struct_diff_df['fields'] = struct_diff_df[col_list].sum(axis=1)
struct_diff_df.head()
# Out:
#                                swagger  info  host  basePath  schemes  \
# X
# 1forge.com                           1     1     1         1        1
# 6-dot-authentiqio.appspot.com        1     1     1         1        1
# adafruit.com                         1     1     1         1        1
# adobe.com:aem                        1     1     1         1        1
# adyen.com:CheckoutService            0     1     0         0        0
#
#                                consumes  produces  paths  definitions  \
# X
# 1forge.com                            0         1      1            0
# 6-dot-authentiqio.appspot.com         0         0      1            1
# adafruit.com                          0         1      1            1
# adobe.com:aem                         0         0      1            1
# adyen.com:CheckoutService             0         0      1            0
#
#                                parameters   ...    tags  externalDocs  title  \
# ...

# %%
labels_struct_diff = struct_diff_df['pam_fit$clustering']

# %%
path_diff_df = pd.read_csv('PAMpath_diff.csv',index_col='X')
path_diff_df = path_diff_df.iloc[:,1:]
path_diff_df.head()
# Out:
#                                paths  operations  pam_fit$clustering
# X
# 1forge.com                         2           2                   1
# 6-dot-authentiqio.appspot.com      5          14                   2
# adafruit.com                      34          69                   3
# adobe.com:aem                     27          31                   4
# adyen.com:CheckoutService          2           2                   1

# %%
structdf = pd.read_csv('PAMcomplete0518.csv',index_col='X')
structdf = structdf.iloc[:,1:]
structdf['fields'] = structdf[col_list].sum(axis=1)
structdf.head()
# Out:
#                                swagger  info  host  basePath  schemes  \
# X
# 1forge.com                           1     1     1         1        1
# 6-dot-authentiqio.appspot.com        1     1     1         1        1
# adafruit.com                         1     1     1         1        1
# adobe.com:aem                        1     1     1         1        1
# adyen.com:CheckoutService            0     1     0         0        0
#
#                                consumes  produces  paths  definitions  \
# X
# 1forge.com                            0         1      1            0
# 6-dot-authentiqio.appspot.com         0         0      1            1
# adafruit.com                          0         1      1            1
# adobe.com:aem                         0         0      1            1
# adyen.com:CheckoutService             0         0      1            0
#
#                                parameters   ...    tags  externalDocs  title  \
# ...

# %%
labels_struct = structdf['pam_fit$clustering']

# %%
pathdf = pd.read_csv('PAMpath0518.csv',index_col='X')
pathdf = pathdf.iloc[:,1:]
pathdf.head()
# Out:
#                                paths  operations  pam_fit$clustering
# X
# 1forge.com                         2           2                   1
# 6-dot-authentiqio.appspot.com      5          14                   2
# adafruit.com                      34          69                   3
# adobe.com:aem                     27          31                   4
# adyen.com:CheckoutService          2           2                   1

# %% [markdown]
# ## Calculations

# %%
import statistics

# %% [markdown]
# ### Extensiveness

# %%
print("standard deviation of data")
print(pathdf.std())
print("variance of data")
print(pathdf.var())
# Out:
# standard deviation of data
# paths                 36.302439
# operations            69.399694
# pam_fit$clustering     4.823958
# dtype: float64
# variance of data
# paths                 1317.867087
# operations            4816.317462
# pam_fit$clustering      23.270567
# dtype: float64

# %%
print("standard deviation of data")
print(path_diff_df.std())
print("variance of data")
print(path_diff_df.var())
# Out:
# standard deviation of data
# paths                 37.301821
# operations            72.347571
# pam_fit$clustering     4.979346
# dtype: float64
# variance of data
# paths                 1391.425853
# operations            5234.170992
# pam_fit$clustering      24.793884
# dtype: float64

# %% [markdown]
# ### Completness

# %%
print("standard deviation of data")
print(labels_struct.std())
print("variance of data")
print(labels_struct.var())
# Out:
# standard deviation of data
# 2.183195847091905
# variance of data
# 4.76634410675934

# %%
print("standard deviation of data")
print(labels_struct_diff.std())
print("variance of data")
print(labels_struct_diff.var())
# Out:
# standard deviation of data
# 2.271589608547791
# variance of data
# 5.160119349662305
