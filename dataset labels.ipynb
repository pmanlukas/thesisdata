# %% [markdown]
# # Creation of a data set containing labels of classes for the data samples
#
# In this notebook we create two distinct data sets, that contain the labels for each sample of our main data set.
# The labels are put into their own distinct data set, so that it is easier to use them while training a new model.

# %%
import pickle
import json
import pandas as pd
import numpy as np

# %% [markdown]
# ## labels of path clusters

# %%
pathdf = pd.read_csv('PAMpath0518.csv',index_col='X')
pathdf = pathdf.iloc[:,1:]
pathdf.head()
# Out:
#                                paths  operations  pam_fit$clustering
# X
# 1forge.com                         2           2                   1
# 6-dot-authentiqio.appspot.com      5          14                   2
# adafruit.com                      34          69                   3
# adobe.com:aem                     27          31                   4
# adyen.com:CheckoutService          2           2                   1

# %%
path_labels = pathdf.copy()
path_labels = path_labels.drop(['paths', 'operations'], 1)
path_labels.index.names = ['API']
path_labels.rename(columns={'pam_fit$clustering':'label'}, inplace=True)
path_labels
# Out:
#                                        label
# API
# 1forge.com                                 1
# 6-dot-authentiqio.appspot.com              2
# adafruit.com                               3
# adobe.com:aem                              4
# adyen.com:CheckoutService                  1
# adyen.com:PaymentService                   5
# adyen.com:RecurringService                 1
# afterbanks.com                             6
# agco-ats.com                               7
# airport-web.appspot.com                    8
# amadeus.com                                9
# amazonaws.com:AWSMigrationHub              4
# amazonaws.com:acm                          9
# amazonaws.com:acm-pca                      4
# amazonaws.com:alexaforbusiness            10
# amazonaws.com:apigateway                  11
# amazonaws.com:application-autoscaling      9
# amazonaws.com:appstream                    3
# amazonaws.com:appsync                     12
# amazonaws.com:athena                       9
# amazonaws.com:autoscaling                 10
# amazonaws.com:autoscaling-plans           13
# amazonaws.com:batch                        4
# amazonaws.com:budgets                      4
# amazonaws.com:ce                          13
# amazonaws.com:cloud9                       9
# amazonaws.com:clouddirectory              11
# amazonaws.com:cloudformation              10
# amazonaws.com:cloudfront                   3
# amazonaws.com:cloudhsm                    12
# ...                                      ...
# weber-gesamtausgabe.de                    14
# whapi.com:accounts                        17
# whapi.com:bets                            14
# whapi.com:locations                       17
# whapi.com:numbers                          8
# whapi.com:sessions                        15
# whapi.com:sportsdata                       2
# who-hosts-this.com                         1
# wikimedia.org                             12
# windows.net:batch-BatchService            10
# windows.net:graphrbac                     12
# winning.email                              6
# winsms.co.za                               5
# wmata.com:bus-realtime                     1
# wmata.com:bus-route                       13
# wmata.com:incidents                       14
# wmata.com:rail-realtime                    1
# wmata.com:rail-station                     2
# wordassociations.net                       1
# wordnik.com                                4
# wowza.com                                 11
# wso2apistore.com:transform                 1
# xero.com                                   7
# xkcd.com                                   1
# yunbi.com                                  9
# zalando.com                                9
# zappiti.com                                5
# zoom.us                                   11
# zoomconnect.com                           12
# zuora.com                                 16
#
# [1034 rows x 1 columns]

# %%
path_labels.to_csv('path_labels0518.csv', encoding='utf8')

# %% [markdown]
# ## labels of structure clusters

# %%
pamcompdf = pd.read_csv('PAMcomplete0518.csv',index_col='X')
pamcompdf = pamcompdf.iloc[:,1:]
pamcompdf.head()
# Out:
#                                swagger  info  host  basePath  schemes  \
# X
# 1forge.com                           1     1     1         1        1
# 6-dot-authentiqio.appspot.com        1     1     1         1        1
# adafruit.com                         1     1     1         1        1
# adobe.com:aem                        1     1     1         1        1
# afterbanks.com                       1     1     1         1        1
#
#                                consumes  produces  paths  definitions  \
# X
# 1forge.com                            0         1      1            0
# 6-dot-authentiqio.appspot.com         0         0      1            1
# adafruit.com                          0         1      1            1
# adobe.com:aem                         0         0      1            1
# afterbanks.com                        0         1      1            1
#
#                                parameters         ...          security  tags  \
# X                                                 ...
# 1forge.com                              0         ...                 0     0
# 6-dot-authentiqio.appspot.com           1         ...                 0     0
# adafruit.com                            1         ...                 1     0
# adobe.com:aem                           0         ...                 1     0
# afterbanks.com                          0         ...                 0     0
#
#                                externalDocs  title  description  \
# X
# 1forge.com                                0      1            1
# 6-dot-authentiqio.appspot.com             0      1            1
# adafruit.com                              0      1            1
# adobe.com:aem                             0      1            1
# afterbanks.com                            0      1            1
#
#                                termsOfService  contact  license  version  \
# X
# 1forge.com                                  0        1        0        1
# 6-dot-authentiqio.appspot.com               1        1        1        1
# adafruit.com                                0        0        0        1
# adobe.com:aem                               0        1        0        1
# afterbanks.com                              0        0        0        1
#
#                                pam_fit$clustering
# X
# 1forge.com                                      1
# 6-dot-authentiqio.appspot.com                   2
# adafruit.com                                    3
# adobe.com:aem                                   3
# afterbanks.com                                  1
#
# [5 rows x 22 columns]

# %%
spec_key_complete = []
spec_key_complete.append('swagger')
spec_key_complete.append('info')
spec_key_complete.append('host')
spec_key_complete.append('basePath')
spec_key_complete.append('schemes')
spec_key_complete.append('consumes')
spec_key_complete.append('produces')
spec_key_complete.append('paths')
spec_key_complete.append('definitions')
spec_key_complete.append('parameters')
spec_key_complete.append('responses')
spec_key_complete.append('securityDefinitions')
spec_key_complete.append('security')
spec_key_complete.append('tags')
spec_key_complete.append('title')
spec_key_complete.append('description')
spec_key_complete.append('termsOfService')
spec_key_complete.append('contact')
spec_key_complete.append('license')
spec_key_complete.append('version')
spec_key_complete.append('externalDocs')

# %%
structure_labels = pamcompdf.copy()
structure_labels = structure_labels.drop(spec_key_complete, 1)
structure_labels.index.names = ['API']
structure_labels.rename(columns={'pam_fit$clustering':'label'}, inplace=True)
structure_labels.head()
# Out:
#                                label
# API
# 1forge.com                         1
# 6-dot-authentiqio.appspot.com      2
# adafruit.com                       3
# adobe.com:aem                      3
# afterbanks.com                     1

# %%
structure_labels.to_csv('structure_labels0518.csv', encoding='utf8')

# %%
with open('obj/'+ 'path_labels0518' + '.pkl', 'wb') as f:
        pickle.dump(path_labels, f, pickle.HIGHEST_PROTOCOL)

# %%
with open('obj/'+ 'structure_labels0518' + '.pkl', 'wb') as f:
        pickle.dump(structure_labels, f, pickle.HIGHEST_PROTOCOL)

# %%
import sys
# !{sys.executable} -m pip install azure
# Out:
# Requirement already satisfied: azure in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (3.0.0)
# Requirement already satisfied: azure-storage-blob~=1.1 in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from azure) (1.1.0)
# Requirement already satisfied: azure-keyvault~=0.3.7 in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from azure) (0.3.7)
# Requirement already satisfied: azure-servicemanagement-legacy~=0.20.6 in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from azure) (0.20.6)
# Requirement already satisfied: azure-graphrbac~=0.40.0 in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from azure) (0.40.0)
# Requirement already satisfied: azure-batch~=4.0 in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from azure) (4.1.3)
# Requirement already satisfied: azure-datalake-store~=0.0.18 in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from azure) (0.0.19)
# Requirement already satisfied: azure-cosmosdb-table~=1.0 in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from azure) (1.0.2)
# Requirement already satisfied: azure-servicebus~=0.21.1 in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from azure) (0.21.1)
# Requirement already satisfied: azure-storage-queue~=1.1 in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from azure) (1.1.0)
# Requirement already satisfied: azure-mgmt~=2.0 in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from azure) (2.0.0)
# Requirement already satisfied: azure-storage-file~=1.1 in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from azure) (1.1.0)
# Requirement already satisfied: azure-servicefabric~=6.1.2.9 in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from azure) (6.1.2.9)
# Requirement already satisfied: azure-eventgrid~=0.1.0 in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from azure) (0.1.0)
# Requirement already satisfied: azure-storage-nspkg>=2.0.0 in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from azure-storage-blob~=1.1->azure) (3.0.0)
# Requirement already satisfied: azure-storage-common<1.2.0,>=1.1.0 in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from azure-storage-blob~=1.1->azure) (1.1.0)
# Requirement already satisfied: azure-common>=1.1.5 in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from azure-storage-blob~=1.1->azure) (1.1.9)
# Requirement already satisfied: azure-nspkg>=2.0.0 in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from azure-keyvault~=0.3.7->azure) (2.0.0)
# Requirement already satisfied: msrestazure~=0.4.7 in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from azure-keyvault~=0.3.7->azure) (0.4.28)
# Requirement already satisfied: requests in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from azure-servicemanagement-legacy~=0.20.6->azure) (2.18.4)
# Requirement already satisfied: msrest~=0.4.5 in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from azure-datalake-store~=0.0.18->azure) (0.4.28)
# Requirement already satisfied: cffi in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from azure-datalake-store~=0.0.18->azure) (1.11.5)
# Requirement already satisfied: adal>=0.4.2 in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from azure-datalake-store~=0.0.18->azure) (0.5.1)
# Requirement already satisfied: azure-cosmosdb-nspkg>=2.0.0 in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from azure-cosmosdb-table~=1.0->azure) (2.0.2)
# Requirement already satisfied: futures in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from azure-cosmosdb-table~=1.0->azure) (3.1.1)
# Requirement already satisfied: cryptography in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from azure-cosmosdb-table~=1.0->azure) (2.2.2)
# Requirement already satisfied: python-dateutil in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from azure-cosmosdb-table~=1.0->azure) (2.6.1)
# Requirement already satisfied: azure-mgmt-recoveryservices~=0.2.0 in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from azure-mgmt~=2.0->azure) (0.2.0)
# Requirement already satisfied: azure-mgmt-dns~=1.2 in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from azure-mgmt~=2.0->azure) (1.2.0)
# Requirement already satisfied: azure-mgmt-batch~=5.0 in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from azure-mgmt~=2.0->azure) (5.0.0)
# Requirement already satisfied: azure-mgmt-sql~=0.8.5 in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from azure-mgmt~=2.0->azure) (0.8.6)
# Requirement already satisfied: azure-mgmt-datalake-store~=0.3.0 in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from azure-mgmt~=2.0->azure) (0.3.0)
# Requirement already satisfied: azure-mgmt-advisor~=1.0 in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from azure-mgmt~=2.0->azure) (1.0.1)
# Requirement already satisfied: azure-mgmt-compute~=3.0 in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from azure-mgmt~=2.0->azure) (3.0.1)
# Requirement already satisfied: azure-mgmt-cognitiveservices~=2.0 in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from azure-mgmt~=2.0->azure) (2.0.0)
# Requirement already satisfied: azure-mgmt-containerregistry~=1.0 in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from azure-mgmt~=2.0->azure) (1.0.1)
# Requirement already satisfied: azure-mgmt-scheduler~=1.1 in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from azure-mgmt~=2.0->azure) (1.1.3)
# Requirement already satisfied: azure-mgmt-marketplaceordering~=0.1.0 in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from azure-mgmt~=2.0->azure) (0.1.0)
# Requirement already satisfied: azure-mgmt-reservations~=0.1.0 in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from azure-mgmt~=2.0->azure) (0.1.0)
# Requirement already satisfied: azure-mgmt-web~=0.34.1 in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from azure-mgmt~=2.0->azure) (0.34.1)
# Requirement already satisfied: azure-mgmt-hanaonazure~=0.1.0 in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from azure-mgmt~=2.0->azure) (0.1.0)
# Requirement already satisfied: azure-mgmt-cosmosdb~=0.3.1 in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from azure-mgmt~=2.0->azure) (0.3.1)
# Requirement already satisfied: azure-mgmt-powerbiembedded~=1.0 in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from azure-mgmt~=2.0->azure) (1.0.0)
# Requirement already satisfied: azure-mgmt-search~=1.0 in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from azure-mgmt~=2.0->azure) (1.0.0)
# Requirement already satisfied: azure-mgmt-servermanager~=1.2 in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from azure-mgmt~=2.0->azure) (1.2.0)
# Requirement already satisfied: azure-mgmt-subscription~=0.1.0 in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from azure-mgmt~=2.0->azure) (0.1.0)
# Requirement already satisfied: azure-mgmt-eventgrid~=0.4.0 in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from azure-mgmt~=2.0->azure) (0.4.0)
# Requirement already satisfied: azure-mgmt-network~=1.7 in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from azure-mgmt~=2.0->azure) (1.7.1)
# Requirement already satisfied: azure-mgmt-commerce~=1.0 in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from azure-mgmt~=2.0->azure) (1.0.1)
# Requirement already satisfied: azure-mgmt-consumption~=2.0 in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from azure-mgmt~=2.0->azure) (2.0.0)
# Requirement already satisfied: azure-mgmt-loganalytics~=0.1.0 in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from azure-mgmt~=2.0->azure) (0.1.0)
# Requirement already satisfied: azure-mgmt-managementpartner~=0.1.0 in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from azure-mgmt~=2.0->azure) (0.1.0)
# Requirement already satisfied: azure-mgmt-rdbms~=0.1.0 in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from azure-mgmt~=2.0->azure) (0.1.0)
# Requirement already satisfied: azure-mgmt-iothub~=0.4.0 in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from azure-mgmt~=2.0->azure) (0.4.0)
# Requirement already satisfied: azure-mgmt-storage~=1.5 in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from azure-mgmt~=2.0->azure) (1.5.0)
# Requirement already satisfied: azure-mgmt-notificationhubs~=1.0 in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from azure-mgmt~=2.0->azure) (1.0.0)
# Requirement already satisfied: azure-mgmt-media~=0.2.0 in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from azure-mgmt~=2.0->azure) (0.2.0)
# Requirement already satisfied: azure-mgmt-relay~=0.1.0 in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from azure-mgmt~=2.0->azure) (0.1.0)
# Requirement already satisfied: azure-mgmt-redis~=5.0 in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from azure-mgmt~=2.0->azure) (5.0.0)
# Requirement already satisfied: azure-mgmt-servicebus~=0.4.0 in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from azure-mgmt~=2.0->azure) (0.4.0)
# Requirement already satisfied: azure-mgmt-recoveryservicesbackup~=0.1.1 in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from azure-mgmt~=2.0->azure) (0.1.1)
# Requirement already satisfied: azure-mgmt-servicefabric~=0.1.0 in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from azure-mgmt~=2.0->azure) (0.1.0)
# Requirement already satisfied: azure-mgmt-monitor~=0.4.0 in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from azure-mgmt~=2.0->azure) (0.4.0)
# Requirement already satisfied: azure-mgmt-billing~=0.1.0 in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from azure-mgmt~=2.0->azure) (0.1.0)
# Requirement already satisfied: azure-mgmt-applicationinsights~=0.1.1 in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from azure-mgmt~=2.0->azure) (0.1.1)
# Requirement already satisfied: azure-mgmt-datafactory~=0.4.0 in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from azure-mgmt~=2.0->azure) (0.4.0)
# Requirement already satisfied: azure-mgmt-datalake-analytics~=0.3.0 in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from azure-mgmt~=2.0->azure) (0.3.0)
# Requirement already satisfied: azure-mgmt-logic~=2.1 in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from azure-mgmt~=2.0->azure) (2.1.0)
# Requirement already satisfied: azure-mgmt-keyvault~=0.40.0 in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from azure-mgmt~=2.0->azure) (0.40.0)
# Requirement already satisfied: azure-mgmt-containerservice~=3.0 in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from azure-mgmt~=2.0->azure) (3.0.1)
# Requirement already satisfied: azure-mgmt-eventhub~=1.2 in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from azure-mgmt~=2.0->azure) (1.2.0)
# Requirement already satisfied: azure-mgmt-devtestlabs~=2.1 in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from azure-mgmt~=2.0->azure) (2.2.0)
# Requirement already satisfied: azure-mgmt-machinelearningcompute~=0.4.0 in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from azure-mgmt~=2.0->azure) (0.4.0)
# Requirement already satisfied: azure-mgmt-iothubprovisioningservices~=0.1.0 in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from azure-mgmt~=2.0->azure) (0.1.0)
# Requirement already satisfied: azure-mgmt-containerinstance~=0.3.1 in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from azure-mgmt~=2.0->azure) (0.3.1)
# Requirement already satisfied: azure-mgmt-batchai~=0.2.0 in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from azure-mgmt~=2.0->azure) (0.2.0)
# Requirement already satisfied: azure-mgmt-msi~=0.1.0 in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from azure-mgmt~=2.0->azure) (0.1.0)
# Requirement already satisfied: azure-mgmt-authorization~=0.30.0 in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from azure-mgmt~=2.0->azure) (0.30.0)
# Requirement already satisfied: azure-mgmt-cdn~=2.0 in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from azure-mgmt~=2.0->azure) (2.0.0)
# Requirement already satisfied: azure-mgmt-resource~=1.2 in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from azure-mgmt~=2.0->azure) (1.2.2)
# Requirement already satisfied: azure-mgmt-trafficmanager~=0.40.0 in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from azure-mgmt~=2.0->azure) (0.40.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from requests->azure-servicemanagement-legacy~=0.20.6->azure) (3.0.4)
# Requirement already satisfied: idna<2.7,>=2.5 in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from requests->azure-servicemanagement-legacy~=0.20.6->azure) (2.6)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from requests->azure-servicemanagement-legacy~=0.20.6->azure) (1.22)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from requests->azure-servicemanagement-legacy~=0.20.6->azure) (2018.1.18)
# Requirement already satisfied: isodate>=0.6.0 in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from msrest~=0.4.5->azure-datalake-store~=0.0.18->azure) (0.6.0)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from msrest~=0.4.5->azure-datalake-store~=0.0.18->azure) (0.8.0)
# Requirement already satisfied: pycparser in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from cffi->azure-datalake-store~=0.0.18->azure) (2.18)
# Requirement already satisfied: PyJWT>=1.0.0 in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from adal>=0.4.2->azure-datalake-store~=0.0.18->azure) (1.6.1)
# Requirement already satisfied: asn1crypto>=0.21.0 in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from cryptography->azure-cosmosdb-table~=1.0->azure) (0.24.0)
# Requirement already satisfied: six>=1.4.1 in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from cryptography->azure-cosmosdb-table~=1.0->azure) (1.11.0)
# Requirement already satisfied: azure-mgmt-nspkg>=2.0.0 in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from azure-mgmt-recoveryservices~=0.2.0->azure-mgmt~=2.0->azure) (2.0.0)
# Requirement already satisfied: azure-mgmt-datalake-nspkg>=2.0.0 in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from azure-mgmt-datalake-store~=0.3.0->azure-mgmt~=2.0->azure) (2.0.0)
# Requirement already satisfied: oauthlib>=0.6.2 in c:\users\lukas\appdata\local\continuum\anaconda3\envs\openapi\lib\site-packages (from requests-oauthlib>=0.5.0->msrest~=0.4.5->azure-datalake-store~=0.0.18->azure) (2.0.7)
# thinc 6.10.2 requires pathlib<2.0.0,>=1.0.0, which is not installed.
# spacy 2.0.11 requires pathlib, which is not installed.
# mkl-random 1.0.1 requires cython, which is not installed.
# mkl-fft 1.0.0 requires cython, which is not installed.
# spacy 2.0.11 has requirement regex==2017.4.5, but you'll have regex 2017.11.9 which is incompatible.
# You are using pip version 10.0.0, however version 10.0.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %% [markdown]
# # Upload data set to blob storage
# - https://docs.microsoft.com/en-us/azure/storage/blobs/storage-quickstart-blobs-python
#
# - https://github.com/Azure-Samples/storage-blobs-python-quickstart/blob/master/example.py

# %%
import os, uuid, sys
from azure.storage.blob import BlockBlobService, PublicAccess

# %%
block_blob_service = BlockBlobService(account_name='openapilp', account_key='4FHmQftrYn99IkPj4tQgGDjyjF8bOPUAu4aQhF54Frb70uI5p9p5zPQkqZRnRhVd4d4ueWAtcFd0KozqRTJtvg==')

# %%
container_name ='labelsdataset'
block_blob_service.create_container(container_name)
# Out:
# Client-Request-ID=18c30db4-5dd5-11e8-9eff-c69ded18204b Retry policy did not allow for a retry: Server-Timestamp=Tue, 22 May 2018 15:30:45 GMT, Server-Request-ID=93dd1f47-401e-00b3-78e1-f13469000000, HTTP status code=409, Exception=The specified container already exists.ErrorCode: ContainerAlreadyExists<?xml version="1.0" encoding="utf-8"?><Error><Code>ContainerAlreadyExists</Code><Message>The specified container already exists.RequestId:93dd1f47-401e-00b3-78e1-f13469000000Time:2018-05-22T15:30:46.5267917Z</Message></Error>.
# False

# %%
block_blob_service.set_container_acl(container_name, public_access=PublicAccess.Container)

# %%
def uploadFile(container_name, local_file_name, full_path_to_file):
    print(str(block_blob_service.create_blob_from_path(container_name, local_file_name, full_path_to_file)))

# %%
path_filename = 'path_labels0518.csv'

# %%
struct_filename = 'structure_labels0518.csv'

# %%
block_blob_service.create_blob_from_path(container_name, path_filename, 'C:\\Users\\lukas\\PycharmProjects\\monimporter\\path_labels0518.csv')

# %%
block_blob_service.create_blob_from_path(container_name, struct_filename, 'C:\\Users\\lukas\\PycharmProjects\\monimporter\\structure_labels0518.csv')

# %% [markdown]
# List the created blobs

# %%
print("\nList blobs in the container")
generator = block_blob_service.list_blobs(container_name)
for blob in generator:
    print("\t Blob name: " + blob.name)
# Out:
# List blobs in the container
# 	 Blob name: path_labels.csv
# 	 Blob name: path_labels0518.csv
# 	 Blob name: structure_labels.csv
# 	 Blob name: structure_labels0518.csv

# %% [markdown]
# You could download any of these two blobs by using the following snippet
# ```
# block_blob_service.get_blob_to_path(container_name, local_file_name, full_path_to_file2)
# ```
