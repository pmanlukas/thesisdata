# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.plot([0,1,2,4,9,16,20,10,4,3,2]);

# %%
x = np.linspace(0, 10, 20)
y = x**2.0

# %%
x
# Out:
# array([ 0.        ,  0.52631579,  1.05263158,  1.57894737,  2.10526316,
#         2.63157895,  3.15789474,  3.68421053,  4.21052632,  4.73684211,
#         5.26315789,  5.78947368,  6.31578947,  6.84210526,  7.36842105,
#         7.89473684,  8.42105263,  8.94736842,  9.47368421, 10.        ])

# %%
plt.plot(x,y)

# %%
x = np.linspace(0,10,20)
y1 = x**2.0
y2 = x**1.5
plt.loglog(x,y1,"bo-", linewidth=2, markersize=12, label="First")
plt.loglog(x,y2, "gs-", linewidth=2, markersize=12, label="Second")
plt.xlabel("$X$")
plt.ylabel("$Y$")
plt.axis([-0.5,10.5,-5,105])
plt.legend(loc="upper right")
plt.savefig("myplot.pdf")
# Out:
# C:\Users\lukas\PycharmProjects\monimporter\venv\lib\site-packages\matplotlib\axes\_base.py:3129: UserWarning: Attempted to set non-positive xlimits for log-scale axis; invalid limits will be ignored.
#   'Attempted to set non-positive xlimits for log-scale axis; '
# C:\Users\lukas\PycharmProjects\monimporter\venv\lib\site-packages\matplotlib\axes\_base.py:3449: UserWarning: Attempted to set non-positive ylimits for log-scale axis; invalid limits will be ignored.
#   'Attempted to set non-positive ylimits for log-scale axis; '

# %%
x=np.logspace(0,1,10) 
y=x**2 
plt.loglog(x,y,"bo-")

# %%
x = np.random.normal(size=1000)

# %%
plt.hist(x);

# %%
plt.hist(x, normed=True, bins=np.linspace(-5,5,21));
# Out:
# C:\Users\lukas\PycharmProjects\monimporter\venv\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
x = np.random.gamma(2,3,100000)

# %%
plt.hist(x, bins=30);

# %%
plt.hist(x, bins=30, normed=True);
# Out:
# C:\Users\lukas\PycharmProjects\monimporter\venv\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
plt.figure()

# %%
x = np.linspace(0,10,20)

# %%
y1 = x**2.0

# %%
y2 = x**1.5

# %%
plt.plot(x, y1, "bo-", linewidth=2, markersize=12)

# %%
plt.plot([0,1,2], [0,1,4], "rd-")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d7cabaebd4ff> in <module>()
# ----> 1 plt.plot([0,1,2], [0,1,4], "rd-")
#
# NameError: name 'plt' is not defined
