# %% [markdown]
# # Download Specs
# In this notebook we download all specs from the gathered URLs, store them as a dict, pickle the dict and upload it to our blob storage in azure

# %%
import pickle
import json
import pandas as pd
import numpy as np
import requests
import os, uuid, sys
from azure.storage.blob import BlockBlobService, PublicAccess

# %% [markdown]
# ### helper functions

# %%
def pickleobj(name, obj):
    with open('obj/'+ name + '.pkl', 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)
    print("pickled {}".format(name))

# %% [markdown]
# ## add azure credentials

# %%
block_blob_service = BlockBlobService(account_name='openapilp', account_key='4FHmQftrYn99IkPj4tQgGDjyjF8bOPUAu4aQhF54Frb70uI5p9p5zPQkqZRnRhVd4d4ueWAtcFd0KozqRTJtvg==') 

container_name ='specs'

block_blob_service.set_container_acl(container_name, public_access=PublicAccess.Container)

def uploadFile(container_name, local_file_name, full_path_to_file):
    print(str(block_blob_service.create_blob_from_path(container_name, local_file_name, full_path_to_file)))

def listBlobs(contname):
    print("\nList blobs in the container")
    generator = block_blob_service.list_blobs(contname)
    for blob in generator:
        print("\t Blob name: " + blob.name)

# %%
specsUrl = {}

with open('obj/specsUrl21052018.pkl', 'rb') as handle:
    specsUrl = pickle.load(handle)

# %%
def getjson(url):
    req = requests.get(url)
    specification = req.json()
    return specification

# %%
def getspec(dicts):
    specdict = {}
    for url in dicts:
        spec = getjson(dicts[url])
        specdict[url] = spec
    print("success")
    return specdict

# %%
for url in specsUrl:
    print(specsUrl[url])
# Out:
# https://api.apis.guru/v2/specs/1forge.com/0.0.1/swagger.json
# https://api.apis.guru/v2/specs/6-dot-authentiqio.appspot.com/6/swagger.json
# https://api.apis.guru/v2/specs/adafruit.com/2.0.0/swagger.json
# https://api.apis.guru/v2/specs/adobe.com/aem/1.3.0/swagger.json
# https://api.apis.guru/v2/specs/adyen.com/CheckoutService/32/openapi.json
# https://api.apis.guru/v2/specs/adyen.com/PaymentService/30/openapi.json
# https://api.apis.guru/v2/specs/adyen.com/RecurringService/25/openapi.json
# https://api.apis.guru/v2/specs/afterbanks.com/3.0.0/swagger.json
# https://api.apis.guru/v2/specs/agco-ats.com/v1/swagger.json
# https://api.apis.guru/v2/specs/airport-web.appspot.com/v1/swagger.json
# https://api.apis.guru/v2/specs/amadeus.com/1.2/swagger.json
# https://api.apis.guru/v2/specs/amazonaws.com/AWSMigrationHub/2017-05-31/swagger.json
# https://api.apis.guru/v2/specs/amazonaws.com/acm/2015-12-08/swagger.json
# ...

# %%
specsJson = getspec(specsUrl)
# Out:
# success

# %%
keys = list(specsJson.keys())
len(keys)
print(specsJson[keys[1]])
# Out:
# {'swagger': '2.0', 'schemes': ['https'], 'host': '6-dot-authentiqio.appspot.com', 'basePath': '/', 'info': {'contact': {'email': 'hello@authentiq.com', 'name': 'Authentiq team', 'url': 'http://authentiq.io/support'}, 'description': 'Strong authentication, without the passwords.', 'license': {'name': 'Apache 2.0', 'url': 'http://www.apache.org/licenses/LICENSE-2.0.html'}, 'termsOfService': 'http://authentiq.com/terms/', 'title': 'Authentiq', 'version': '6', 'x-apisguru-categories': ['security'], 'x-logo': {'backgroundColor': '#F26641', 'url': 'https://api.apis.guru/v2/cache/logo/https_www.authentiq.com_theme_images_authentiq-logo-a-inverse.svg'}, 'x-origin': [{'format': 'swagger', 'url': 'https://raw.githubusercontent.com/AuthentiqID/authentiq-docs/master/docs/swagger/issuer.yaml', 'version': '2.0'}], 'x-preferred': True, 'x-providerName': '6-dot-authentiqio.appspot.com'}, 'parameters': {'AuthentiqID': {'description': 'Authentiq ID to register', 'in': 'body', 'name': 'body', 'required
# ...

# %%
pickleobj('specjson210518', specsJson)
# Out:
# pickled specjson210518

# %% [markdown]
# ### upload to azure

# %%
name = 'specs210518'
full_path_to_file = 'C:\\Users\\lukas\\PycharmProjects\\monimporter\\specs210518.json'

# %%
def to_json(dicts):
    with open('specs210518.json', 'w') as fp:
        json.dump(dicts,fp)

# %%
uploadFile(container_name, name, full_path_to_file)

# %%
listBlobs(container_name)
# Out:
# List blobs in the container
# 	 Blob name: specjson210518
# 	 Blob name: specs210518
# 	 Blob name: specsUrl21052018

# %%
to_json(specsJson)
